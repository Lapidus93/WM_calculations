# %%
import pandas as pd
from datetime import datetime
import wm_tac_ops as ops
from ground_engine import GroundEngine, BattleContext
from create_units import build_brigade_template
from tactical_engine import tact_battle


def brigade_stat(df,level):

    return pd.pivot_table(df,
               columns='status',
              index=level,
              values='soldier_uid',
              aggfunc='count')

# %%
config = {
    "soldier_id": 12,
    "squad_id": 3,
    "platoon_id": 3,
    "company_id": 3,
    "battalion_id": 10,
    "armor_cnt": 0,
}

inf_df, armor_df = build_brigade_template(config)

with pd.ExcelWriter("player_brigade.xlsx", engine="openpyxl") as writer:
    inf_df.to_excel(writer, sheet_name="inf", index=False)
    armor_df.to_excel(writer, sheet_name="armor", index=False)



config = {
    "soldier_id": 12,
    "squad_id": 3,
    "platoon_id": 3,
    "company_id": 3,
    "battalion_id": 7,
    "armor_cnt": 0,
}

inf_df, armor_df = build_brigade_template(config)

with pd.ExcelWriter("enemy_brigade.xlsx", engine="openpyxl") as writer:
    inf_df.to_excel(writer, sheet_name="inf", index=False)
    armor_df.to_excel(writer, sheet_name="armor", index=False)

# %%
pl = pd.read_excel("player_brigade.xlsx")
en = pd.read_excel("enemy_brigade.xlsx")

# %%
brigade_stat(pl,'battalion_uid').sort_values('alive',ascending=False)
# Out:
# status         alive  killed
# battalion_uid
# B10              295      29
# B5               292      32
# B3               283      41
# B9               274      50
# B4               271      53
# B7               270      54
# B8               251      73
# B1               209     115
# B6               204     120
# B2               199     125

# %%
brigade_stat(en,'battalion_uid')
# Out:
# status         alive  killed
# battalion_uid
# B1             231.0    93.0
# B2             324.0     NaN
# B3             324.0     NaN
# B4             241.0    83.0
# B5             202.0   122.0
# B6             265.0    59.0
# B7             227.0    97.0

# %%
TACTICAL_BUTTLE_NUM = 19
TACTICAL_COMMENT = 'B10 на север в горы'
START_TIME = datetime(2026, 5, 13, 10, 0)

PLAYER_FILE = "player_brigade.xlsx"
ENEMY_FILE = "enemy_brigade.xlsx"

PLAYER_LEVEL = "battalion"
PLAYER_FORMATIONS = ["B10"]
PLAYER_ARMOR_COUNT = 0
PLAYER_COVER_RANGE = (0,1)

ENEMY_LEVEL = "battalion"
ENEMY_FORMATIONS = ["B5"]
ENEMY_ARMOR_COUNT = 0
ENEMY_COVER_RANGE = (1,3)

TARGET_UNITS_PER_SIDE = 6

MIN_BATTLES = 3
MAX_BATTLES = 15

DISTANCE_RANGE = (1, 2)
ELEVATION_RANGE = (0, 2)

PLAYER_OUTPUT_FILE = "player_brigade.xlsx"
ENEMY_OUTPUT_FILE = "enemy_brigade.xlsx"

#PLAYER_OUTPUT_FILE = "player_brigade_after_battle.xlsx"
#ENEMY_OUTPUT_FILE = "enemy_brigade_after_battle.xlsx"
LOG_OUTPUT_FILE = "tactical_battle_log.xlsx"


TIME_STEP_MINUTES = 15



files = {
    'PLAYER_FILE': PLAYER_FILE,
    'ENEMY_FILE': ENEMY_FILE,
    'PLAYER_OUTPUT_FILE': PLAYER_OUTPUT_FILE,
    'ENEMY_OUTPUT_FILE': ENEMY_OUTPUT_FILE,
    'LOG_OUTPUT_FILE': LOG_OUTPUT_FILE,
}


player_data = {'PLAYER_LEVEL':PLAYER_LEVEL,
        'PLAYER_FORMATIONS':PLAYER_FORMATIONS,
        'PLAYER_ARMOR_COUNT':PLAYER_ARMOR_COUNT,
               'PLAYER_COVER_RANGE':PLAYER_COVER_RANGE}

enemy_data = {'ENEMY_LEVEL':ENEMY_LEVEL,
        'ENEMY_FORMATIONS':ENEMY_FORMATIONS,
        'ENEMY_ARMOR_COUNT':ENEMY_ARMOR_COUNT,
              'ENEMY_COVER_RANGE':ENEMY_COVER_RANGE}

other_data = {
    'TARGET_UNITS_PER_SIDE': TARGET_UNITS_PER_SIDE,
    'MIN_BATTLES': MIN_BATTLES,
    'MAX_BATTLES': MAX_BATTLES,
    'DISTANCE_RANGE': DISTANCE_RANGE,
    'ELEVATION_RANGE': ELEVATION_RANGE,
    'START_TIME': START_TIME,

    'TACTICAL_BUTTLE_NUM': TACTICAL_BUTTLE_NUM,
    'TACTICAL_BATTLE_TIME': START_TIME,
    'TACTICAL_COMMENT': TACTICAL_COMMENT,
}

tact_battle(files, player_data, enemy_data, other_data)
# Out:
# start
# C:\Users\Kirill\1) ONELIGHT APP\WM_calculations\force_manager.py:559: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0 0 0 0]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   master_indexed.loc[common_uids, col] = changed_df.loc[common_uids, col]
# C:\Users\Kirill\1) ONELIGHT APP\WM_calculations\force_manager.py:559: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0 0 0 0]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   master_indexed.loc[common_uids, col] = changed_df.loc[common_uids, col]
# C:\Users\Kirill\1) ONELIGHT APP\WM_calculations\force_manager.py:559: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[nan nan nan nan]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_indexed.loc[common_uids, col] = changed_df.loc[common_uids, col]
# C:\Users\Kirill\1) ONELIGHT APP\WM_calculations\tactical_engine.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([existing_df, prepared_new_df], ignore_index=True)
# ============================================================
# Тактическая битва #19
# Проведено наземных боёв: 5
# ------------------------------------------------------------
# Общая статистика | победы blue: 1 | поражения blue: 3 | прочее: 1 | потери blue: 17 inf / 0 arm | потери red: 0 inf / 0 arm
#
# Файлы сохранены:
# - player_brigade.xlsx
# - enemy_brigade.xlsx
# - tactical_battle_log.xlsx

# %%
pl = pd.read_excel("player_brigade.xlsx")
en = pd.read_excel("enemy_brigade.xlsx")

# %%
brigade_stat(pl,'battalion_uid').sum()
# Out:
# status
# alive     2754.0
# killed     486.0
# dtype: float64

# %%
brigade_stat(en,'battalion_uid')
# Out:
# status         alive  killed
# battalion_uid
# B1             231.0    93.0
# B2             324.0     NaN
# B3             324.0     NaN
# B4             241.0    83.0
# B5             254.0    70.0
# B6             265.0    59.0
# B7             324.0     NaN

# %%
brigade_stat(pl[pl['battalion_uid']=='B5'],'squad_uid')
#B5-C1-P1-S2
# Out:
# status       alive  killed
# squad_uid
# B5-C1-P1-S1   11.0     1.0
# B5-C1-P1-S2   11.0     1.0
# B5-C1-P1-S3    9.0     3.0
# B5-C1-P2-S1    9.0     3.0
# B5-C1-P2-S2    7.0     5.0
# B5-C1-P2-S3    8.0     4.0
# B5-C1-P3-S1   11.0     1.0
# B5-C1-P3-S2    8.0     4.0
# B5-C1-P3-S3   11.0     1.0
# B5-C2-P1-S1   12.0     NaN
# B5-C2-P1-S2   12.0     NaN
# B5-C2-P1-S3   12.0     NaN
# B5-C2-P2-S1   12.0     NaN
# B5-C2-P2-S2   12.0     NaN
# B5-C2-P2-S3   12.0     NaN
# B5-C2-P3-S1   12.0     NaN
# B5-C2-P3-S2   12.0     NaN
# B5-C2-P3-S3   12.0     NaN
# B5-C3-P1-S1   11.0     1.0
# B5-C3-P1-S2   10.0     2.0
# B5-C3-P1-S3   12.0     NaN
# B5-C3-P2-S1   12.0     NaN
# B5-C3-P2-S2   12.0     NaN
# B5-C3-P2-S3   10.0     2.0
# B5-C3-P3-S1   10.0     2.0
# B5-C3-P3-S2   12.0     NaN
# B5-C3-P3-S3   10.0     2.0

# %%
pl[pl['platoon_uid']=='B2-C1-P1'].sum()
# Out:
# soldier_uid          B2-C1-P1-S1-U1B2-C1-P1-S1-U2B2-C1-P1-S1-U3B2-C...
# global_soldier_id                                                16779
# soldier_id                                                         315
# squad_id                                                            84
# platoon_id                                                          42
# company_id                                                          42
# battalion_id                                                        84
# battalion_uid        B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2B2...
# company_uid          B2-C1B2-C1B2-C1B2-C1B2-C1B2-C1B2-C1B2-C1B2-C1B...
# platoon_uid          B2-C1-P1B2-C1-P1B2-C1-P1B2-C1-P1B2-C1-P1B2-C1-...
# squad_uid            B2-C1-P1-S1B2-C1-P1-S1B2-C1-P1-S1B2-C1-P1-S1B2...
# status               alivealivealivealivealivealivealivealivealivea...
# power                                                               42
# side                                                               0.0
# inf_kills                                                           20
# apc_kills                                                            0
# dtype: object
