# %%
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import wm_unit as wmu
import pandas as pd

import pandas as pd
a1 = pd.read_excel('A1.xlsx').iloc[:100]
b1 = pd.read_excel('B1.xlsx').iloc[:100]

u1 = wmu.Unit(unit_id="1",  alive_df=a1,  cas_df=pd.DataFrame())
u2 = wmu.Unit(unit_id="2",  alive_df=b1,  cas_df=pd.DataFrame())

# %%
u1.attack_unit(u2)
# Out:
#         ######
#         1
#         ######
#
# elev_pos 0 ?
#  2
# cover_level 0 ?
# target_distance 0 ?
#  1
# enemy_unit_id id1 ?
#  2
# berserk_mode 0 ?
#         ######
#         2
#         ######
#
# elev_pos 0 ?
#  1
# cover_level 0 ?
# target_distance 0 ?
#  1
# enemy_unit_id id1 ?
#  1
# berserk_mode 0 ?
# 1 before elev 2.2612499999999995
# 1 after_elev 3.165749999999999
# 2 before elev 13.567499999999999
# 2 after_elev 9.691071428571428
# поражение
# 0.03 0.18
# 1 13
