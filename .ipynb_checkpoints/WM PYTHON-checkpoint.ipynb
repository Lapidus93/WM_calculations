# %%
armor = pd.DataFrame([[1,'apc',9,8,0],
                  [2,'apc',9,8,0]],columns=['armor_id','type','transport','power','kill_count'])

# %%
from datetime import datetime, timedelta
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import wm_unit as wmu
import pandas as pd

def calculate_force(force):
    available_force = 0
    casualties = 0
    for i in force:
        available_force += len(i.alive_df)
        casualties += len(i.cas_df)
    return available_force,casualties

def next_turn(current_time):
    current_time += timedelta(minutes=15)
    print(current_time)
    return current_time


def evacuation_and_regroup(unit,cas_avacuated,current_time):
    cas_to_add = unit.cas_df
    cas_to_add['side'] = unit.side
    cas_to_add['unit'] = unit.unit_id
    cas_to_add['evac_time'] = current_time
    cas_avacuated = cas_avacuated.append(cas_to_add)
    if 0 < len(unit.alive_df) <= 12:
        unit.size = 'SQ'
    elif 13 < len(unit.alive_df) <= 40:
        unit.size = 'PT'
    elif len(unit.alive_df) > 40:
        unit.size = 'CM'
    if 'type' in unit.alive_df.columns:
        unit.size = 'ARMOR'
    unit.cas_df = pd.DataFrame()
    
    return unit, cas_avacuated


def abandon_cas(unit,cas_abandoned,current_time):
    cas_to_add = unit.cas_df
    cas_to_add['side'] = unit.side
    cas_to_add['unit'] = unit.unit_id
    cas_to_add['evac_time'] = current_time
    cas_abandoned = cas_abandoned.append(cas_to_add)
    unit.cas_df = pd.DataFrame()    

    return unit, cas_abandoned


a1 = pd.read_excel('A1.xlsx').iloc[:100]
a2 = pd.read_excel('A1.xlsx').iloc[:25]
a3 = pd.read_excel('A1.xlsx').iloc[:25]
a4 = pd.read_excel('A1.xlsx').iloc[:25]
a5 = pd.read_excel('A1.xlsx').iloc[:25]
a6 = pd.read_excel('A1.xlsx').iloc[:75]

a1 = wmu.Unit(unit_id="a1",  alive_df=a1,  cas_df=pd.DataFrame(),side='red')
a2 = wmu.Unit(unit_id="a2",  alive_df=a2,  cas_df=pd.DataFrame(),side='red')
a3 = wmu.Unit(unit_id="a3",  alive_df=a3,  cas_df=pd.DataFrame(),side='red')
a4 = wmu.Unit(unit_id="a4",  alive_df=a4,  cas_df=pd.DataFrame(),side='red')
a5 = wmu.Unit(unit_id="a5",  alive_df=a5,  cas_df=pd.DataFrame(),side='red')
a6 = wmu.Unit(unit_id="a6",  alive_df=a6,  cas_df=pd.DataFrame(),side='red')

b1 = pd.read_excel('A1.xlsx').iloc[:100]
b2 = pd.read_excel('A1.xlsx').iloc[:100]
b1 = wmu.Unit(unit_id="b1",  alive_df=b1,  cas_df=pd.DataFrame(),side='blue')
b2 = wmu.Unit(unit_id="b2",  alive_df=b2,  cas_df=pd.DataFrame(),side='blue')

attackers = [b1,b2]
defenders = [a1,a2,a3,a4,a5,a6]

current_time = datetime(2026,1,9,6,0)
logs = pd.DataFrame()
cas_avacuated = pd.DataFrame()
cas_abandoned = pd.DataFrame()

# %%
current_time = next_turn(current_time)
# Out:
# 2026-01-09 06:15:00

# %%
logs = a1.attack_unit(b1,logs,current_time)
# Out:
#         ######
#         a1
#         ######
#
# elev_pos 0 ?
# cover_level 2 ?
# target_distance 3 ?
# enemy_unit_id id1 ?
# berserk_mode 0 ?
#         ######
#         b1
#         ######
#
# elev_pos 0 ?
# cover_level 2 ?
# target_distance 3 ?
# enemy_unit_id id1 ?
# berserk_mode 0 ?
# атака без ответа
# 12 32
# 14 54
# -40
# 0

# %%
a1
# Out:
# Unit(unit_id=a1, size=CM, alive_df=100, cas_df=0, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
b1
# Out:
# Unit(unit_id=b1, size=CM, alive_df=21, cas_df=22, last_parameters={'elev_pos': 0, 'cover_level': 1, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
b1, cas_avacuated = evacuation_and_regroup(b1,cas_avacuated,current_time)
# Out:
# <ipython-input-68-00212c09020b>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cas_avacuated = cas_avacuated.append(cas_to_add)

# %%
b1, cas_abandoned = abandon_cas(b1,cas_abandoned,current_time)
# Out:
# <ipython-input-68-00212c09020b>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cas_abandoned = cas_abandoned.append(cas_to_add)

# %%
calculate_force(defenders)
# Out:
# (275, 0)

# %%
calculate_force(attackers)
# Out:
# (121, 0)

# %%
b1
# Out:
# Unit(unit_id=b1, size=CM, alive_df=100, cas_df=0, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
a1
# Out:
# Unit(unit_id=a1, size=CM, alive_df=100, cas_df=0, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})
