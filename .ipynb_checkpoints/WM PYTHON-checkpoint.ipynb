# %%
from datetime import datetime, timedelta
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import pandas as pd

import wm_unit as wmu
import wm_tac_ops as to

wf = pd.read_excel('A1.xlsx').iloc[:100]
c1 = wmu.Unit(unit_id="c1",  alive_df=wf,  cas_df=pd.DataFrame(),side='blue')
c2 = wmu.Unit(unit_id="c2",  alive_df=wf,  cas_df=pd.DataFrame(),side='blue')
c3 = wmu.Unit(unit_id="c3",  alive_df=wf,  cas_df=pd.DataFrame(),side='blue')


p1 = wmu.Unit(unit_id="p1",  alive_df=wf,  cas_df=pd.DataFrame(),side='red')
p2 = wmu.Unit(unit_id="p2",  alive_df=wf,  cas_df=pd.DataFrame(),side='red')
p3 = wmu.Unit(unit_id="p3",  alive_df=wf,  cas_df=pd.DataFrame(),side='red')


defenders = [p1,p2,p3]
attackers = [c1,c2,c3]

current_time = datetime(2026,1,21,13,0)
logs = pd.DataFrame()
cas_avacuated = pd.DataFrame()
cas_abandoned = pd.DataFrame()

# %%
armor = pd.DataFrame([[1,'apc',9,8,0],
                  [2,'apc',9,8,0]],columns=['armor_id','type','transport','power','kill_count'])

# %%
armor = wmu.Unit(unit_id="armor",  alive_df=armor,  cas_df=pd.DataFrame(),side='blue')

# %%
mech =  wmu.Unit(unit_id="mech",  alive_df=wf, armor_part = armor , cas_df=pd.DataFrame(),side='blue')

# %%
mech.armor_part
# Out:
# Unit(unit_id=armor, size=ARMOR, alive_df=2, cas_df=0, armor_part=0, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
c1.attack_unit(mech,logs,current_time)
# Out:
#         ######
#         c1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
# enemy_unit_id id1 ?
# berserk_mode 0 ?
#         ######
#         mech
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
# enemy_unit_id id1 ?
# berserk_mode 0 ?
# 134 57
# атака без ответа
# 29 0 29
#                  time attack_unit_side attack_unit attack_unit_size  \
# 0 2026-01-21 13:00:00             blue          c1               CM
#
#    attack_unit_alive_force  attack_cas defend_unit defend_unit_size  \
# 0                      100           0        mech               CM
#
#    defend_unit_alive_force  defend_cas  result
# 0                       42          29  победа

# %%
mech
# Out:
# Unit(unit_id=mech, size=CM, alive_df=13, cas_df=87, armor_part=2, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
def manage_casualties(alive_df, cas_df, cas):
    if cas > len(alive_df):
        cas = len(alive_df)
            

    # 1. случайный выбор cas строк
    selected = alive_df.sample(n=cas, replace=False)
    
    # 2. добавляем их в cas_df
    cas_df = pd.concat([cas_df, selected], ignore_index=True)
    
    # 3. удаляем выбранные строки из alive_df
    alive_df = alive_df.drop(selected.index).reset_index(drop=True)
        
    return alive_df, cas_df

# %%
alive_df
# Out:
# Empty DataFrame
# Columns: [armor_id, type, transport, power, kill_count]
# Index: []

# %%
cas_df
# Out:
#    armor_id type  transport  power  kill_count
# 0         2  apc          9      8           0
# 1         1  apc          9      8           0

# %%
mech
# Out:
# Unit(unit_id=mech, size=CM, alive_df=100, cas_df=0, armor_part=2, last_parameters={'elev_pos': 0, 'cover_level': 0, 'target_distance': 0, 'enemy_unit_id': 'id1', 'berserk_mode': 0})

# %%
70% не двигаться близко
40% не двигаться далеко

# %%
70 *.25
# Out:
# 17.5

# %%
logs = mech.attack_unit(p1,logs,current_time)
# Out:
#         ######
#         mech
#         ######
#
# elev_pos 0 ?
# cover_level 1 ?
# target_distance 1 ?
# enemy_unit_id p1 ?
# berserk_mode 0 ?
#         ######
#         p1
#         ######
#
# elev_pos 0 ?
# cover_level 1 ?
# target_distance 1 ?
# enemy_unit_id mech ?
# berserk_mode 0 ?
# 51 67
# ничья
# 0.06 0.06
# Потери mech 3 ( 0 + 3 )
# Потери p1 7 ( 7 + 0 )

# %%
    def armor_attack_check_and_result(self,armor_unit):

        def rpg_shot(move,distance):
            cas = 0
            chance = 70
        
            if distance == '1':
                chance = chance*0.5
            if move == '1':
                chance = chance*0.25
            chance = int(round(chance,0))
    
            shot_result = random.randint(1,100)
            if shot_result <=chance:
                cas+=1
        
            return cas



        if len(armor_unit.armor_part.alive_df) >0:
            armor_attack_request = input('Атакуем броню?')
            if armor_attack_request=='1':   
                shots = 1
                if self.size =='CM':
                    shots = 3
                
            
                move = input('Броня двигается?')
                distance = input('Броня далеко?')
        
                cas = 0
            
                for i in range(shots):
                    cas+= rpg_shot(move,distance)

            if cas > len(armor_unit.armor_part.alive_df):
                cas = len(armor_unit.armor_part.alive_df)
            print('Подбита ',cas,' единиц техника')

            alive_df, cas_df = manage_casualties(armor_unit.armor_part.alive_df, armor_unit.armor_part.cas_df, cas)
            armor_unit.armor_part.alive_df = alive_df
            armor_unit.armor_part.cas_df = cas_df

            return armor_unit
        else:
            return armor_unit
