# %%
from datetime import datetime, timedelta
import random 
import pandas as pd

import wm_unit as wmu
import wm_tac_ops as to

current_time = datetime(2026,1,21,13,0)
logs = pd.DataFrame()

wf = pd.read_excel('A1.xlsx').iloc[:100]


c1 = wmu.Unit(unit_id="c1", overall_type="inf",personal_type="inf", alive_df=wf,  cas_df=pd.DataFrame(),side='blue')

armor1 = pd.DataFrame([[1,'apc',9,8,0,0],
                      [2,'apc',9,8,0,0],
                     [3,'apc',9,8,0,0],
                     [4,'apc',9,8,0,0],
                      [5,'apc',9,8,0,0],
                      [6,'apc',9,8,0,0],
                      [7,'apc',9,8,0,0],
                      [8,'apc',9,8,0,0],
                      [9,'apc',9,8,0,0],
                  [10,'apc',9,8,0,0]],columns=['armor_id','type','transport','power','inf_kills','apc_kills'])

armor1 = wmu.Unit(unit_id="armor1", overall_type="arm",personal_type="arm", alive_df=armor1,  cas_df=pd.DataFrame(),side='blue')
armor1.update_current_type()

c1.armor_part = armor1
c1.update_current_type()

c2 = wmu.Unit(unit_id="c2", overall_type="inf",personal_type="inf", alive_df=wf,  cas_df=pd.DataFrame(),side='blue')
c2.update_current_type()

armor2 = pd.DataFrame([[1,'apc',9,8,0,0],
                      [2,'apc',9,8,0,0],
                     [3,'apc',9,8,0,0],
                     [4,'apc',9,8,0,0],
                      [5,'apc',9,8,0,0],
                      [6,'apc',9,8,0,0],
                      [7,'apc',9,8,0,0],
                      [8,'apc',9,8,0,0],
                      [9,'apc',9,8,0,0],
                  [10,'apc',9,8,0,0]],columns=['armor_id','type','transport','power','inf_kills','apc_kills'])

armor2 = wmu.Unit(unit_id="armor2", overall_type="arm",personal_type="arm", alive_df=armor2,  cas_df=pd.DataFrame(),side='blue')

armor2.update_current_type()

# %%
logs.to_excel('logs.xlsx',index=False)

# %%
en_armor = pd.DataFrame([[1,'apc',9,8,0,0],
                      [2,'apc',9,8,0,0],
                     [3,'apc',9,8,0,0],
                     [4,'apc',9,8,0,0],
                      [5,'apc',9,8,0,0]],columns=['armor_id','type','transport','power','inf_kills','apc_kills'])

en_armor = wmu.Unit(unit_id="en_armor", overall_type="arm",personal_type="arm", alive_df=en_armor,  cas_df=pd.DataFrame(),side='red')
en_armor.update_current_type()

ep = pd.read_excel('A1.xlsx').iloc[:30]

enem_pt1 =  wmu.Unit(unit_id="ep1", overall_type="inf",personal_type="inf", alive_df=ep,  cas_df=pd.DataFrame(),side='red')
enem_pt1.update_current_type()

enem_pt2 =  wmu.Unit(unit_id="ep2", overall_type="inf",personal_type="inf", alive_df=ep,  cas_df=pd.DataFrame(),side='red')
enem_pt2.update_current_type()

enem_pt3 =  wmu.Unit(unit_id="ep3", overall_type="inf",personal_type="inf", alive_df=ep,  cas_df=pd.DataFrame(),side='red')
enem_pt3.update_current_type()

# %%
logs = c1.base_attack(enem_pt1,logs,current_time)
# Out:
#         ######
#         c1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
#  3
# enemy_unit_id id1 ?
#  ep1
# berserk_mode 0 ?
#         ######
#         ep1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
#  2
# target_distance 0 ?
#  3
# enemy_unit_id id1 ?
#  c1
# berserk_mode 0 ?
# Механизированный c1 атакует пехотный отряд ep1
# атака без ответа
# ep1  вжат землю
# Бронированный armor1 наносит потери 9
# ep1  вжат землю
# В стрелковом бою c1 атакует с результатом разгром
# Потери c1 3  Потери ep1 6

# %%
enem_pt1
# Out:
# Unit(unit_id=ep1, overall_type=inf,personal_type=inf,size=PT, alive_df=15, cas_df=15, armor_part=0, last_parameters={'elev_pos': 0, 'cover_level': 2, 'target_distance': 3, 'enemy_unit_id': 'c1', 'berserk_mode': 0})

# %%
logs = armor2.base_attack(enem_pt1,logs,current_time)
# Out:
#         ######
#         armor2
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 2 ?
# enemy_unit_id id1 ?
#  ep1
# berserk_mode 0 ?
#         ######
#         ep1
#         ######
#
# elev_pos 0 ?
# cover_level 2 ?
# target_distance 3 ?
#  2
# enemy_unit_id c1 ?
#  armor2
# berserk_mode 0 ?
# ep1  вжат землю
# Бронированный armor2 обстрелял пехотный отряд ep1
# Потери ep1 4

# %%
logs
# Out:
#           current_time initiator log_blue_id log_blue_type  \
# 0  2026-01-21 13:00:00      blue      armor2           arm
# 0  2026-01-21 13:00:00       red      armor2           arm
# 0  2026-01-21 13:15:00      blue      armor2           arm
# 0  2026-01-21 13:15:00       red      armor2           arm
# 0  2026-01-21 13:30:00      blue      armor2           arm
# 0  2026-01-21 13:45:00      blue          c1          mech
# 0  2026-01-21 13:45:00      blue      armor2           arm
#
#    log_blue_inf_force  log_blue_arm_force  log_blue_cas_inf  \
# 0                   0                  10                 0
# 0                   0                  10                 0
# 0                   0                   9                 0
# 0                   0                   9                 0
# 0                   0                   9                 0
# 0                 100                  10                 3
# 0                   0                   9                 0
#
# ...

# %%
current_time = to.next_turn(current_time)
# Out:
# 2026-01-21 14:00:00
