# %%
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import wm_unit as wmu
import pandas as pd

import pandas as pd
a1 = pd.read_excel('A1.xlsx').iloc[:10]
b1 = pd.read_excel('B1.xlsx').iloc[:10]

u1 = wmu.Unit(unit_id="A1", size="SQ", alive_df=a1,  cas_df=pd.DataFrame(), size_decrease =0.9)
u2 = wmu.Unit(unit_id="b1", size="SQ", alive_df=b1,  cas_df=pd.DataFrame(), size_decrease =0.9)


u1.attack_unit(u2)
# Out:
# A1 9.0
#
#         ######
#         A1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
#  2
# enemy_unit_id id1 ?
# b1 9.0
#
#         ######
#         b1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
#  2
# enemy_unit_id id1 ?
# разгром
# 2
# 2

# %%
u1.attack_unit(u2)
# Out:
# A1 1.8
#
#         ######
#         A1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 2 ?
# enemy_unit_id id1 ?
# b1 -1.8
#
#         ######
#         b1
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 2 ?
# enemy_unit_id id1 ?
# ничья
# 2
# 4
