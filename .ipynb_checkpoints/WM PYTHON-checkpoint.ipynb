# %%
armor = pd.DataFrame([[1,'apc',9,8,0],
                  [2,'apc',9,8,0]],columns=['armor_id','type','transport','power','kill_count'])

# %%
from datetime import datetime, timedelta
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import wm_unit as wmu
import pandas as pd

def calculate_force(force):
    available_force = 0
    casualties = 0
    for i in force:
        available_force += len(i.alive_df)
        casualties += len(i.cas_df)
    return available_force,casualties

def next_turn(current_time):
    current_time += timedelta(minutes=15)
    print(current_time)
    return current_time


def evacuation_and_regroup(unit,cas_avacuated,current_time):
    cas_to_add = unit.cas_df
    cas_to_add['side'] = unit.side
    cas_to_add['unit'] = unit.unit_id
    cas_to_add['evac_time'] = current_time
    cas_avacuated = cas_avacuated.append(cas_to_add)
    if 0 < len(unit.alive_df) <= 12:
        unit.size = 'SQ'
    elif 13 < len(unit.alive_df) <= 40:
        unit.size = 'PT'
    elif len(unit.alive_df) > 40:
        unit.size = 'CM'
    if 'type' in unit.alive_df.columns:
        unit.size = 'ARMOR'
    unit.cas_df = pd.DataFrame()
    
    return unit, cas_avacuated


def abandon_cas(unit,cas_abandoned,current_time):
    cas_to_add = unit.cas_df
    cas_to_add['side'] = unit.side
    cas_to_add['unit'] = unit.unit_id
    cas_to_add['evac_time'] = current_time
    cas_abandoned = cas_abandoned.append(cas_to_add)
    unit.cas_df = pd.DataFrame()    

    return unit, cas_abandoned

def save_units(list_of_sides):
    for side in list_of_sides:
        for podr in side:
            podr.alive_df.to_csv(podr.unit_id+'.csv',index=False)

            
def load_units(list_of_sides):
    for side in list_of_sides:
        for podr in side:
            podr.alive_df = pd.read_csv(podr.unit_id+'.csv')


wf = pd.read_excel('A1.xlsx').iloc[:120]
c1 = wmu.Unit(unit_id="c1",  alive_df=wf,  cas_df=pd.DataFrame(),side='blue')
c2 = wmu.Unit(unit_id="c2",  alive_df=wf,  cas_df=pd.DataFrame(),side='blue')

wf = pd.read_excel('A1.xlsx').iloc[:70]
ws = pd.read_excel('A1.xlsx').iloc[:65]

ec1 = wmu.Unit(unit_id="ec1",  alive_df=wf,  cas_df=pd.DataFrame(),side='red')
ec2 = wmu.Unit(unit_id="ec2",  alive_df=ws,  cas_df=pd.DataFrame(),side='red')

defenders = [ec1,ec2]
attackers = [c1,c2]

current_time = datetime(2026,1,21,15,0)
logs = pd.DataFrame()
cas_avacuated = pd.DataFrame()
cas_abandoned = pd.DataFrame()

# %%
save_units([defenders,attackers])

# %%
load_units([attackers])

# %%
str(current_time)
# Out:
# '2026-01-21 15:15:00'

# %%
calculate_force(defenders)
# Out:
# (135, 0)

# %%
calculate_force(attackers)
# Out:
# (230, 0)

# %%
current_time = next_turn(current_time)
# Out:
# 2026-01-21 17:00:00

# %%
logs
# Out:
#                  time attack_unit_side attack_unit attack_unit_size  \
# 0 2026-01-21 15:00:00             blue          c2               CM
# 0 2026-01-21 15:00:00             blue          c1               CM
# 0 2026-01-21 15:15:00             blue          c2               CM
#
#    attack_unit_alive_force  attack_cas defend_unit defend_unit_size  \
# 0                      120           3         ec2               CM
# 0                      120           7         ec1               CM
# 0                      117           0         ec1               CM
#
#    defend_unit_alive_force  defend_cas     result
# 0                       65          25     победа
# 0                       70           1  поражение
# 0                       69          29     победа

# %%
logs = c2.attack_unit(ec1,logs,current_time)
# Out:
#         ######
#         c2
#         ######
#
# elev_pos 0 ?
#
# cover_level 1 ?
#
# target_distance 0 ?
#
# enemy_unit_id ec2 ?
# ec1
# berserk_mode 1 ?
#
#
#         ######
#         ec1
#         ######
#
# elev_pos 0 ?
#
# cover_level 1 ?
#
# target_distance 4 ?
# 0
# enemy_unit_id c1 ?
# c2
# berserk_mode 0 ?
#
# победа
# 0.18 0.03
# 29 0

# %%
logs = c1.attack_unit(ec1,logs,current_time)
# Out:
#         ######
#         c1
#         ######
#
# elev_pos 0 ?
#
# cover_level 1 ?
# 0
# target_distance 4 ?
#
# enemy_unit_id ec1 ?
#
# berserk_mode 1 ?
# 0
#
#         ######
#         ec1
#         ######
#
# elev_pos 0 ?
#
# cover_level 1 ?
#
# target_distance 0 ?
# 4
# enemy_unit_id id1 ?
# c1
# berserk_mode 0 ?
#
# поражение
# 0.03 0.18
# 1 7

# %%
b1, cas_avacuated = evacuation_and_regroup(b1,cas_avacuated,current_time)
# Out:
# <ipython-input-68-00212c09020b>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cas_avacuated = cas_avacuated.append(cas_to_add)

# %%
w5, cas_abandoned = abandon_cas(w5,cas_abandoned,current_time)
# Out:
# <ipython-input-2-d3cb3ba4e177>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cas_abandoned = cas_abandoned.append(cas_to_add)

# %%
for side in [defenders, attackers]:
    for podr in side:
        podr.alive_df.to_csv(podr.unit_id+'.csv',index=False)
