# %%
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import random 
from typing import Optional
##### import random
from collections import Counter
import wm_unit as wmu
import pandas as pd

import pandas as pd
a1 = pd.read_excel('A1.xlsx').iloc[:100]
b1 = pd.read_excel('B1.xlsx').iloc[:100]

u1 = wmu.Unit(unit_id="1",  alive_df=a1,  cas_df=pd.DataFrame())
u2 = wmu.Unit(unit_id="2",  alive_df=b1,  cas_df=pd.DataFrame())

# %%
armor = pd.DataFrame([[1,'apc',9,8,0],
                  [2,'apc',9,8,0]],columns=['armor_id','type','transport','power','kill_count'])
ua1 = wmu.Unit(unit_id="1a",  alive_df=armor,  cas_df=pd.DataFrame())

# %%
ua1.alive_df
# Out:
#    armor_id type  transport  power  kill_count
# 0         1  apc          9      8           0
# 1         2  apc          9      8           0

# %%
ua1.attack_unit(u2)
# Out:
#         ######
#         1a
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
# enemy_unit_id 2 ?
# berserk_mode 0 ?
#         ######
#         2
#         ######
#
# elev_pos 0 ?
# cover_level 0 ?
# target_distance 0 ?
# enemy_unit_id id1 ?
# berserk_mode 0 ?
# атака без ответа
# поражение
# 0.03 0.18
# 4
